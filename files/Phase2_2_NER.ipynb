# %% [markdown]
# # Phase 2.2 — Named Entity Recognition (NER)
#
# - **Dataset:** `preprocessed_reviews.csv` (Yelp Restaurant Reviews)
# - **ที่มาของ Dataset:** HuggingFace (Yelp Review Polarity) + Web Scraping จาก Yelp.com รวม 2,000 rows
# - **Model:** spaCy Pre-trained `en_core_web_sm`
# - **เป้าหมาย:** ใช้ spaCy สกัด Entity (ชื่อคน, องค์กร, สถานที่ ฯลฯ) จาก review แบบ Unsupervised
#   และวิเคราะห์ว่า Entity ใดถูกพูดถึงบ่อย รวมถึงความสัมพันธ์กับ Sentiment

# %% [markdown]
# ## 0. ติดตั้ง Dependencies
#
# รันเซลล์นี้ครั้งแรกเท่านั้น

# %%
import subprocess, sys

libs = ['spacy', 'pandas', 'matplotlib', 'seaborn', 'wordcloud', 'tabulate']
for lib in libs:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', lib, '-q'])

subprocess.check_call([sys.executable, '-m', 'spacy', 'download', 'en_core_web_sm', '-q'])
print('Setup complete')
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Setup complete

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import spacy
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from wordcloud import WordCloud
from IPython.display import display

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 11
sns.set_theme(style='whitegrid')

print('Import complete')
# Out:
# Import complete

# %% [markdown]
# ## 2. โหลด spaCy Model และข้อมูล

# %%
# โหลด spaCy model
# en_core_web_sm = small model เร็ว, เพียงพอสำหรับ NER ทั่วไป
nlp = spacy.load('en_core_web_sm')

# โหลด dataset จาก Phase 1
# ใช้คอลัมน์ 'text' (ต้นฉบับ) ไม่ใช่ text_clean
# เพราะ spaCy ต้องการ context ครบเพื่อจับ Entity ได้แม่นยำ
df = pd.read_csv('preprocessed_reviews.csv')
df['label_name'] = df['label'].map({0: 'Negative', 1: 'Positive'})

print(f'Model     : en_core_web_sm')
print(f'Pipeline  : {nlp.pipe_names}')
print(f'Shape     : {df.shape}')
print(f'Columns   : {df.columns.tolist()}')
print(f'\nLabel distribution:')
print(df['label_name'].value_counts())
# Out:
# Model     : en_core_web_sm
# Pipeline  : ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']
# Shape     : (1653, 9)
# Columns   : ['text', 'label', 'source', 'text_clean', 'text_no_stopwords', 'token_count_clean', 'token_count_nostop', 'tokens', 'label_name']
#
# Label distribution:
# label_name
# Positive    1090
# Negative     563
# Name: count, dtype: int64

# %% [markdown]
# ## 3. ทดสอบ NER บนตัวอย่างก่อน
#
# ก่อนรันทั้ง dataset ทดสอบ 3 review จริงเพื่อดูว่า spaCy จับ Entity อะไรได้บ้าง
#
# | Label | ความหมาย | ตัวอย่างใน Restaurant Review |
# |-------|----------|------------------------------|
# | `ORG` | องค์กร / ร้านอาหาร / แบรนด์ | McDonald's, Nobu, Yelp |
# | `PERSON` | ชื่อคน | Chef John, Gordon |
# | `GPE` | ประเทศ / เมือง / รัฐ | New York, Manhattan |
# | `LOC` | สถานที่ทางภูมิศาสตร์ | Times Square |
# | `DATE` | วันที่ / ช่วงเวลา | last Friday, March |
# | `TIME` | เวลา | 8pm, 30 minutes |
# | `MONEY` | จำนวนเงิน | $25, fifty dollars |
# | `PRODUCT` | สินค้า / ชื่อเมนู | Wagyu burger |

# %%
sample_texts = df['text'].dropna().sample(3, random_state=42).tolist()

for i, text in enumerate(sample_texts):
    sentiment = df[df['text'] == text]['label_name'].values[0]
    doc = nlp(text)

    print(f'[Review {i+1}]  Sentiment: {sentiment}')
    print(f'Text: {text[:200]}...' if len(text) > 200 else f'Text: {text}')
    print(f'  {"Entity":<30} {"Label":<10} Description')
    print('  ' + '-' * 60)
    if doc.ents:
        for ent in doc.ents:
            print(f'  {ent.text:<30} {ent.label_:<10} {spacy.explain(ent.label_)}')
    else:
        print('  (no entities found)')
    print()
# Out:
# [Review 1]  Sentiment: Negative
# Text: I will never buy meat ,milk and eggs in this store. I bought shrimps one time, when i got home. I opened the bags, the smell of smelly came out, also made me throw up. Their vegetable is not fresh any...
#   Entity                         Label      Description
#   ------------------------------------------------------------
#   one                            CARDINAL   Numerals that do not fall under another type
#
# [Review 2]  Sentiment: Negative
# Text: Wir waren heute dort, anl\u00e4sslich unseres Hochzeitstages.\nIch war gespannt, wie sich uns das Lauerturmst\u00fcble pr\u00e4sentiert, nachdem ich hier doch sehr Gegens\u00e4tzliches gelesen hatte.\...
#   Entity                         Label      Description
#   ------------------------------------------------------------
#   nachdem                        ORG        Companies, agencies, institutions, etc.
#   doch sehr                      PERSON     People, including fictional
#   gelesen hatte.\n\n\n           PERSON     People, including fictional
#   Kulisse                        NORP       Nationalities or religious or political groups
#   \nIdyllisch                    PERSON     People, including fictional
#   Charme                         ORG        Companies, agencies, institutions, etc.
#   das                            ORG        Companies, agencies, institutions, etc.
#   dem                            NORP       Nationalities or religious or political groups
#   Torbogen aus                   PERSON     People, including fictional
#   sch\u00f6n                     PERSON     People, including fictional
#   Daf\u00fcr                     GPE        Countries, cities, states
#   Stern                          PERSON     People, including fictional
#   Schlag                         NORP       Nationalities or religious or political groups
#   das Lokal                      PERSON     People, including fictional
#   Zwar                           ORG        Companies, agencies, institutions, etc.
#   sch\u00f6n                     PERSON     People, including fictional
#   k\u00f6nnte gem\u00fctlich     PERSON     People, including fictional
#   extrem klein                   PERSON     People, including fictional
#   Leider                         PERSON     People, including fictional
#   bin nicht                      ORG        Companies, agencies, institutions, etc.
#   Mann                           PERSON     People, including fictional
#   zu eng.                        PERSON     People, including fictional
#   daf\u00fcr                     CARDINAL   Numerals that do not fall under another type
#   der zweite Stern.\nAllerdings  PERSON     People, including fictional
#   Zack                           PERSON     People, including fictional
#   notiert hatte                  PERSON     People, including fictional
#   hatte                          PERSON     People, including fictional
#   Reservierung                   PERSON     People, including fictional
#   Hochzeitstag                   PRODUCT    Objects, vehicles, foods, etc. (not services)
#   h\u00e4tte uns mit             PERSON     People, including fictional
#   Gratulation durchaus Aufmerksamkeit WORK_OF_ART Titles of books, songs, etc.
#   Sicht                          PERSON     People, including fictional
#   k\u00f6nnen.\nDie Apfelschorle PERSON     People, including fictional
#   schmeckte leider garnicht      PERSON     People, including fictional
#   Wie                            PERSON     People, including fictional
#   Billig-Konzentrat              ORG        Companies, agencies, institutions, etc.
#   wurde dort gemischt            PERSON     People, including fictional
#   hatte gefragt vorab).\nDie Karte PERSON     People, including fictional
#   \u00fcbersichtlich             GPE        Countries, cities, states
#   klein                          GPE        Countries, cities, states
#   Schnitzel                      ORG        Companies, agencies, institutions, etc.
#   Fritten                        PERSON     People, including fictional
#   Salat                          ORG        Companies, agencies, institutions, etc.
#   J\u00e4gersauce                PRODUCT    Objects, vehicles, foods, etc. (not services)
#   mein Mann                      PERSON     People, including fictional
#   waren frisch                   PERSON     People, including fictional
#   Salat                          ORG        Companies, agencies, institutions, etc.
#   Sauce                          PERSON     People, including fictional
#   dem Blattsalat                 ORG        Companies, agencies, institutions, etc.
#   Hatte                          PERSON     People, including fictional
#   Kommentar                      GPE        Countries, cities, states
#   Salatteller                    PERSON     People, including fictional
#   Die Schnitzel                  ORG        Companies, agencies, institutions, etc.
#   waren ziemlich viel            PERSON     People, including fictional
#   nicht aus                      ORG        Companies, agencies, institutions, etc.
#   Dose                           PERSON     People, including fictional
#   Meine J\u00e4gersauce          PERSON     People, including fictional
#   waren frisch                   PERSON     People, including fictional
#   Sauce                          PERSON     People, including fictional
#   Pommes                         ORG        Companies, agencies, institutions, etc.
#   hatte                          PRODUCT    Objects, vehicles, foods, etc. (not services)
#   Tische                         ORG        Companies, agencies, institutions, etc.
#   Raum                           ORG        Companies, agencies, institutions, etc.
#   dem                            NORP       Nationalities or religious or political groups
#   Scho\u00df sa\u00df            FAC        Buildings, airports, highways, bridges, etc.
#   Bedienung                      PERSON     People, including fictional
#   Tisch                          PERSON     People, including fictional
#   dem                            NORP       Nationalities or religious or political groups
#   Nachbartisch                   ORG        Companies, agencies, institutions, etc.
#   Karten                         PERSON     People, including fictional
#   geht garnicht.\nAn             ORG        Companies, agencies, institutions, etc.
#   Jubi-Essen                     PERSON     People, including fictional
#   zu laut                        PERSON     People, including fictional
#   geht leider                    PERSON     People, including fictional
#   Anzahl                         PERSON     People, including fictional
#   Kosten der G\u00e4ste und      PERSON     People, including fictional
#   \nIm Sommer                    PERSON     People, including fictional
#   zum Drau\u00dfen               PERSON     People, including fictional
#   kann ich                       PERSON     People, including fictional
#   nicht beurteilen               PERSON     People, including fictional
#   Einrichtungen                  ORG        Companies, agencies, institutions, etc.
#   von uns nicht genutzt wurde    ORG        Companies, agencies, institutions, etc.
#   Unterm Strich                  PERSON     People, including fictional
#   hatte das Ganze                PERSON     People, including fictional
#   sa\u00df                       PRODUCT    Objects, vehicles, foods, etc. (not services)
#   Nachbarin                      GPE        Countries, cities, states
#   Nebentisch                     ORG        Companies, agencies, institutions, etc.
#   Teil                           PERSON     People, including fictional
#   Kette                          PERSON     People, including fictional
#   Fallen                         PERSON     People, including fictional
#
# [Review 3]  Sentiment: Positive
# Text: Our dinner at Different Pointe of View was perfect. We did the chef's tasting menu with the wine pairing and got completely spoiled. The tasting began with a succulent lamb tenderloin, which was a bit...
#   Entity                         Label      Description
#   ------------------------------------------------------------
#   Different Pointe of View       FAC        Buildings, airports, highways, bridges, etc.
#   Norwegian                      NORP       Nationalities or religious or political groups
#   30 hours                       TIME       Times smaller than a day
#   California                     GPE        Countries, cities, states
#   Arizona                        GPE        Countries, cities, states
#   Phoenix                        GPE        Countries, cities, states
#   half an hour                   TIME       Times smaller than a day
#   the end of the evening         DATE       Absolute or relative dates or periods
#   P.S.-                          GPE        Countries, cities, states
#   tonight                        TIME       Times smaller than a day
#   Muahahahahaha                  PERSON     People, including fictional

# %% [markdown]
# ## 4. รัน NER บนข้อมูลทั้งหมด
#
# > **หมายเหตุ:** ใช้ `nlp.pipe()` แทน `.apply()` เพราะเร็วกว่ามาก (Batch Processing ~3-5x)

# %%
TARGET_LABELS = {
    'ORG':     'องค์กร / ร้านอาหาร',
    'PERSON':  'ชื่อคน',
    'GPE':     'ประเทศ / เมือง',
    'LOC':     'สถานที่',
    'DATE':    'วันที่ / ช่วงเวลา',
    'TIME':    'เวลา',
    'MONEY':   'จำนวนเงิน',
    'PRODUCT': 'ชื่อผลิตภัณฑ์ / เมนู',
}

import re

# ============================================================
# BLACKLISTS — คำที่ spaCy จำแนกผิดประจำ
# ============================================================

# ORG: คำที่ไม่ใช่องค์กรแต่ถูก tag ผิด
ORG_BLACKLIST = {
    # 2-letter abbreviations / noise
    'un', 'az', 'ny', 'nj', 'la', 'dc', 'sf',
    # adjectives / sentiments
    'free', 'awesome', 'never', 'always', 'great', 'good', 'bad',
    'best', 'worst', 'nice', 'okay', 'ok', 'amazing', 'terrible',
    'horrible', 'excellent', 'perfect', 'delicious', 'disgusting',
    'fresh', 'cold', 'hot', 'slow', 'expensive', 'cheap',
    # tech / misc
    'wifi', 'yelp', 'uber', 'lyft', 'google', 'instagram',
    # artifacts
    'eta', 'asap', 'fyi', 'btw', 'omg', 'lol', 'hertz',
    # location words that bleed into ORG
    'nyc', 'manhattan', 'brooklyn', 'queens',
}

# PERSON: สถานที่ / สิ่งของ / แบรนด์ที่ spaCy tag เป็นชื่อคน
PERSON_BLACKLIST = {
    # สถานที่ที่ถูก tag เป็นชื่อคน
    'vegas', 'madison', 'bellagio', 'tribeca', 'soho', 'chelsea',
    'brooklyn', 'manhattan', 'harlem', 'midtown', 'downtown',
    'greenwich', 'bleecker', 'houston', 'broadway',
    # แบรนด์ / ร้านที่ถูก tag ผิด
    'eataly', 'nobu', 'carbone', 'shake shack', 'chipotle',
    # คำทั่วไปในร้านอาหาร
    'brunch', 'lunch', 'dinner', 'breakfast', 'waiter', 'waitress',
    'manager', 'chef', 'host', 'hostess', 'server', 'bartender',
    'cashier', 'staff', 'crew',
    # tech / misc
    'wifi', 'yelp', 'google', 'uber',
    # คำ 1 พยางค์ที่ไม่น่าเป็นชื่อ
    'lee', 'kim', 'ann',   # อาจ valid แต่ ambiguous มาก
}

# สถานที่จริง — ถ้า spaCy tag เป็น PERSON ให้ตัดออก
KNOWN_PLACES = {
    'new york', 'new york city', 'nyc', 'manhattan', 'brooklyn',
    'queens', 'bronx', 'staten island', 'las vegas', 'vegas',
    'chicago', 'los angeles', 'miami', 'boston', 'seattle',
    'bellagio', 'tribeca', 'soho', 'chelsea', 'harlem',
    'midtown', 'downtown', 'times square', 'central park',
}

# แบรนด์จริงที่ควรอยู่ใน ORG ไม่ใช่ PERSON
KNOWN_ORGS = {
    'eataly', 'nobu', 'carbone', 'shake shack', 'chipotle',
    'mcdonald', 'starbucks', 'whole foods', 'trader joe',
}


def is_valid_entity(text: str, label: str) -> bool:
    """
    กรอง false-positive entities ออกด้วย 6 rules:
    1. ความยาวขั้นต่ำ >= 2 ตัวอักษร
    2. Blacklist ตาม label (ORG / PERSON)
    3. ตัวเลขล้วน
    4. Punctuation / escape artifact
    5. ORG ต้องมีตัวอักษรจริง >= 3 ตัว
    6. PERSON cross-check: ถ้าเป็นสถานที่หรือแบรนด์ → ตัดออก
    """
    t = text.strip().lower()

    # Rule 1: ความยาวขั้นต่ำ
    if len(t) < 2:
        return False

    # Rule 2: Blacklist ตาม label
    if label == 'ORG'    and t in ORG_BLACKLIST:
        return False
    if label == 'PERSON' and t in PERSON_BLACKLIST:
        return False

    # Rule 3: ตัวเลขล้วน
    if re.fullmatch(r'[\d\s.,]+', t):
        return False

    # Rule 4: Punctuation / escape artifacts
    if re.fullmatch(r'[^a-zA-Z0-9 ]+', t):
        return False

    # Rule 5: ORG ต้องมีตัวอักษรจริง >= 3 ตัว (กัน 'az','un','ny')
    if label == 'ORG' and len(re.sub(r'[^a-zA-Z]', '', t)) < 3:
        return False

    # Rule 6: PERSON cross-check — ถ้าชื่อตรงกับ known place/brand → ตัดออก
    if label == 'PERSON':
        if t in KNOWN_PLACES or t in KNOWN_ORGS:
            return False

    return True


# ============================================================
# RUN NER + FILTER
# ============================================================
all_entities   = []
entity_per_row = []
rejected_count = 0
rejected_log   = []

texts      = df['text'].fillna('').tolist()
sentiments = df['label_name'].tolist()

print(f'กำลังรัน NER บน {len(texts):,} reviews...')

for doc, sentiment in zip(nlp.pipe(texts, batch_size=256), sentiments):
    row_ents = []
    for ent in doc.ents:
        if ent.label_ not in TARGET_LABELS:
            continue

        if not is_valid_entity(ent.text, ent.label_):
            rejected_count += 1
            if len(rejected_log) < 20:  # เก็บตัวอย่างที่ reject ไว้ debug
                rejected_log.append((ent.text, ent.label_))
            continue

        all_entities.append({
            'entity':    ent.text.strip(),
            'label':     ent.label_,
            'sentiment': sentiment,
        })
        row_ents.append({'text': ent.text.strip(), 'label': ent.label_})
    entity_per_row.append(row_ents)

df['entities']     = entity_per_row
df['entity_count'] = df['entities'].apply(len)

ent_df = pd.DataFrame(all_entities)
ent_df['entity_norm'] = ent_df['entity'].str.lower().str.strip()

print(f'Total entities extracted  : {len(ent_df) + rejected_count:,}')
print(f'Rejected (false-positive) : {rejected_count:,}')
print(f'Valid entities kept        : {len(ent_df):,}')
print(f'Unique entities            : {ent_df["entity_norm"].nunique():,}')
print(f'\nEntity type counts (after filter):')
print(ent_df['label'].value_counts().to_string())
print(f'\nตัวอย่าง entities ที่ถูก reject (20 แรก):')
for txt, lbl in rejected_log:
    print(f'  [{lbl}] {txt}')
# Out:
# กำลังรัน NER บน 1,653 reviews...
# Total entities extracted  : 4,507
# Rejected (false-positive) : 491
# Valid entities kept        : 4,016
# Unique entities            : 2,621
#
# Entity type counts (after filter):
# label
# PERSON     1222
# ORG         896
# GPE         593
# DATE        533
# TIME        516
# LOC         114
# MONEY        76
# PRODUCT      66
#
# ตัวอย่าง entities ที่ถูก reject (20 แรก):
#   [ORG] Un
#   [ORG] un
#   [ORG] un
#   [PERSON] Bellagio
#   [ORG] Yelp
#   [MONEY] 10
#   [ORG] OMG
#   [MONEY] 200
#   [MONEY] 50
#   [ORG] Awesome
#   [MONEY] 10
#   [PERSON] Vegas
#   [ORG] NY
#   [PERSON] Vegas
#   [ORG] NY
#   [ORG] AZ
#   [MONEY] 3.29
#   [ORG] Yelp
#   [PERSON] Vegas
#   [MONEY] 42

# %% [markdown]
# ## 5. สถิติภาพรวม — Entity แต่ละประเภทมีจำนวนเท่าไหร่
#
# กราฟแรกตอบคำถามว่า: **review ร้านอาหารพูดถึง Entity ประเภทไหนมากที่สุด?**

# %%
label_counts = ent_df['label'].value_counts().reset_index()
label_counts.columns = ['Label', 'Count']
label_counts['Meaning'] = label_counts['Label'].map(TARGET_LABELS)

print('Entity Type Distribution:')
print('=' * 45)
display(label_counts)

fig, ax = plt.subplots(figsize=(9, 4))
colors = sns.color_palette('Blues_r', len(label_counts))
bars = ax.barh(label_counts['Label'], label_counts['Count'], color=colors)
ax.bar_label(bars, fmt='%d', padding=5, fontsize=9)
ax.set_xlabel('Count')
ax.set_title('Number of Entities per Type', fontsize=13, fontweight='bold')
ax.set_xlim(0, label_counts['Count'].max() * 1.15)
ax.invert_yaxis()

plt.tight_layout()
plt.savefig('ner_type_distribution.png', bbox_inches='tight')
plt.show()
print('Saved: ner_type_distribution.png')
# Out:
# Entity Type Distribution:
# =============================================
#      Label  Count               Meaning
# 0   PERSON   1222                ชื่อคน
# 1      ORG    896    องค์กร / ร้านอาหาร
# 2      GPE    593        ประเทศ / เมือง
# 3     DATE    533     วันที่ / ช่วงเวลา
# 4     TIME    516                  เวลา
# 5      LOC    114               สถานที่
# 6    MONEY     76             จำนวนเงิน
# 7  PRODUCT     66  ชื่อผลิตภัณฑ์ / เมนู
# Saved: ner_type_distribution.png

# %% [markdown]
# ## 6. Top 15 ร้านอาหาร / องค์กร (ORG) ที่ถูกพูดถึงมากที่สุด
#
# ผ่าน **post-filtering 5 rules** เพื่อกรอง false-positive ออก:
# - ตัดคำสั้น (< 2 ตัวอักษร)
# - ตัด blacklist คำที่ spaCy จำแนกผิดบ่อย เช่น `un`, `az`, `never`, `free`, `awesome`
# - ตัดตัวเลขล้วน
# - ตัด punctuation artifacts เช่น `\"\"i`
# - ORG ต้องมีตัวอักษรจริง ≥ 3 ตัว

# %%
org_df = ent_df[ent_df['label'] == 'ORG'].copy()

top_orgs = org_df['entity_norm'].value_counts().head(15).reset_index()
top_orgs.columns = ['Organization', 'Count']
top_orgs.insert(0, 'Rank', range(1, len(top_orgs) + 1))

print('Top 15 Organizations mentioned:')
print('=' * 40)
display(top_orgs.style.hide(axis='index'))

fig, ax = plt.subplots(figsize=(9, 6))
palette = sns.color_palette('Reds_r', len(top_orgs))
bars = ax.barh(top_orgs['Organization'][::-1], top_orgs['Count'][::-1], color=palette[::-1])
ax.bar_label(bars, fmt='%d', padding=5, fontsize=9)
ax.set_xlabel('Mention Count')
ax.set_title('Top 15 Organizations (ORG) in Restaurant Reviews', fontsize=13, fontweight='bold')
ax.set_xlim(0, top_orgs['Count'].max() * 1.15)

plt.tight_layout()
plt.savefig('ner_top_orgs.png', bbox_inches='tight')
plt.show()
print('Saved: ner_top_orgs.png')
# Out:
# Top 15 Organizations mentioned:
# ========================================
# <style type="text/css">
# </style>
# <table id="T_0b560">
#   <thead>
#     <tr>
#       <th id="T_0b560_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_0b560_level0_col1" class="col_heading level0 col1" >Organization</th>
#       <th id="T_0b560_level0_col2" class="col_heading level0 col2" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0b560_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_0b560_row0_col1" class="data row0 col1" >bbq</td>
#       <td id="T_0b560_row0_col2" class="data row0 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_0b560_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_0b560_row1_col1" class="data row1 col1" >starbucks</td>
#       <td id="T_0b560_row1_col2" class="data row1 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_0b560_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_0b560_row2_col1" class="data row2 col1" >mgm</td>
#       <td id="T_0b560_row2_col2" class="data row2 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_0b560_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_0b560_row3_col1" class="data row3 col1" >buffet</td>
#       <td id="T_0b560_row3_col2" class="data row3 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_0b560_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_0b560_row4_col1" class="data row4 col1" >scottsdale</td>
#       <td id="T_0b560_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_0b560_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_0b560_row5_col1" class="data row5 col1" >dragon court</td>
#       <td id="T_0b560_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_0b560_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_0b560_row6_col1" class="data row6 col1" >whole foods</td>
#       <td id="T_0b560_row6_col2" class="data row6 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_0b560_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_0b560_row7_col1" class="data row7 col1" >pepsi</td>
#       <td id="T_0b560_row7_col2" class="data row7 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_0b560_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_0b560_row8_col1" class="data row8 col1" >yelpers</td>
#       <td id="T_0b560_row8_col2" class="data row8 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_0b560_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_0b560_row9_col1" class="data row9 col1" >way</td>
#       <td id="T_0b560_row9_col2" class="data row9 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_0b560_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_0b560_row10_col1" class="data row10 col1" >fleur</td>
#       <td id="T_0b560_row10_col2" class="data row10 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_0b560_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_0b560_row11_col1" class="data row11 col1" >wow</td>
#       <td id="T_0b560_row11_col2" class="data row11 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_0b560_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_0b560_row12_col1" class="data row12 col1" >elena</td>
#       <td id="T_0b560_row12_col2" class="data row12 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_0b560_row13_col0" class="data row13 col0" >14</td>
#       <td id="T_0b560_row13_col1" class="data row13 col1" >kfc</td>
#       <td id="T_0b560_row13_col2" class="data row13 col2" >4</td>
#     </tr>
#     <tr>
#       <td id="T_0b560_row14_col0" class="data row14 col0" >15</td>
#       <td id="T_0b560_row14_col1" class="data row14 col1" >santiago</td>
#       <td id="T_0b560_row14_col2" class="data row14 col2" >4</td>
#     </tr>
#   </tbody>
# </table>
# Saved: ner_top_orgs.png

# %% [markdown]
# ## 7. Top 15 บุคคล (PERSON) ที่ถูกกล่าวถึงมากที่สุด

# %%
person_df = ent_df[ent_df['label'] == 'PERSON'].copy()

top_persons = person_df['entity_norm'].value_counts().head(15).reset_index()
top_persons.columns = ['Person', 'Count']
top_persons.insert(0, 'Rank', range(1, len(top_persons) + 1))

print('Top 15 Persons mentioned:')
print('=' * 40)
display(top_persons.style.hide(axis='index'))

fig, ax = plt.subplots(figsize=(9, 6))
palette = sns.color_palette('Blues_r', len(top_persons))
bars = ax.barh(top_persons['Person'][::-1], top_persons['Count'][::-1], color=palette[::-1])
ax.bar_label(bars, fmt='%d', padding=5, fontsize=9)
ax.set_xlabel('Mention Count')
ax.set_title('Top 15 Persons (PERSON) in Restaurant Reviews', fontsize=13, fontweight='bold')
ax.set_xlim(0, top_persons['Count'].max() * 1.15)

plt.tight_layout()
plt.savefig('ner_top_persons.png', bbox_inches='tight')
plt.show()
print('Saved: ner_top_persons.png')
# Out:
# Top 15 Persons mentioned:
# ========================================
# <style type="text/css">
# </style>
# <table id="T_c5a8a">
#   <thead>
#     <tr>
#       <th id="T_c5a8a_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_c5a8a_level0_col1" class="col_heading level0 col1" >Person</th>
#       <th id="T_c5a8a_level0_col2" class="col_heading level0 col2" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c5a8a_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_c5a8a_row0_col1" class="data row0 col1" >kevin</td>
#       <td id="T_c5a8a_row0_col2" class="data row0 col2" >49</td>
#     </tr>
#     <tr>
#       <td id="T_c5a8a_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_c5a8a_row1_col1" class="data row1 col1" >adam</td>
#       <td id="T_c5a8a_row1_col2" class="data row1 col2" >13</td>
#     </tr>
#     <tr>
#       <td id="T_c5a8a_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_c5a8a_row2_col1" class="data row2 col1" >smith</td>
#       <td id="T_c5a8a_row2_col2" class="data row2 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_c5a8a_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_c5a8a_row3_col1" class="data row3 col1" >eddie</td>
#       <td id="T_c5a8a_row3_col2" class="data row3 col2" >9</td>
#     </tr>
#     <tr>
#       <td id="T_c5a8a_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_c5a8a_row4_col1" class="data row4 col1" >vincent</td>
#       <td id="T_c5a8a_row4_col2" class="data row4 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_c5a8a_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_c5a8a_row5_col1" class="data row5 col1" >adrianne</td>
#       <td id="T_c5a8a_row5_col2" class="data row5 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_c5a8a_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_c5a8a_row6_col1" class="data row6 col1" >andy</td>
#       <td id="T_c5a8a_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_c5a8a_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_c5a8a_row7_col1" class="data row7 col1" >peter</td>
#       <td id="T_c5a8a_row7_col2" class="data row7 col2" >6</td>
#     </tr>
#     <tr>
#       <td id="T_c5a8a_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_c5a8a_row8_col1" class="data row8 col1" >janmichael</td>
#       <td id="T_c5a8a_row8_col2" class="data row8 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_c5a8a_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_c5a8a_row9_col1" class="data row9 col1" >thai villa</td>
#       <td id="T_c5a8a_row9_col2" class="data row9 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_c5a8a_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_c5a8a_row10_col1" class="data row10 col1" >steve</td>
#       <td id="T_c5a8a_row10_col2" class="data row10 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_c5a8a_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_c5a8a_row11_col1" class="data row11 col1" >ben</td>
#       <td id="T_c5a8a_row11_col2" class="data row11 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_c5a8a_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_c5a8a_row12_col1" class="data row12 col1" >erica</td>
#       <td id="T_c5a8a_row12_col2" class="data row12 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_c5a8a_row13_col0" class="data row13 col0" >14</td>
#       <td id="T_c5a8a_row13_col1" class="data row13 col1" >palazzo</td>
#       <td id="T_c5a8a_row13_col2" class="data row13 col2" >5</td>
#     </tr>
#     <tr>
#       <td id="T_c5a8a_row14_col0" class="data row14 col0" >15</td>
#       <td id="T_c5a8a_row14_col1" class="data row14 col1" >mac</td>
#       <td id="T_c5a8a_row14_col2" class="data row14 col2" >5</td>
#     </tr>
#   </tbody>
# </table>
# Saved: ner_top_persons.png

# %% [markdown]
# ## 8. Top 15 สถานที่ (GPE + LOC) ที่พบมากที่สุด

# %%
location_df = ent_df[ent_df['label'].isin(['GPE', 'LOC'])].copy()

top_locations = location_df['entity_norm'].value_counts().head(15).reset_index()
top_locations.columns = ['Location', 'Count']
top_locations.insert(0, 'Rank', range(1, len(top_locations) + 1))

print('Top 15 Locations (GPE + LOC):')
print('=' * 40)
display(top_locations.style.hide(axis='index'))

fig, ax = plt.subplots(figsize=(9, 6))
palette = sns.color_palette('Greens_r', len(top_locations))
bars = ax.barh(top_locations['Location'][::-1], top_locations['Count'][::-1], color=palette[::-1])
ax.bar_label(bars, fmt='%d', padding=5, fontsize=9)
ax.set_xlabel('Mention Count')
ax.set_title('Top 15 Locations (GPE + LOC) in Restaurant Reviews', fontsize=13, fontweight='bold')
ax.set_xlim(0, top_locations['Count'].max() * 1.15)

plt.tight_layout()
plt.savefig('ner_top_locations.png', bbox_inches='tight')
plt.show()
print('Saved: ner_top_locations.png')
# Out:
# Top 15 Locations (GPE + LOC):
# ========================================
# <style type="text/css">
# </style>
# <table id="T_906b8">
#   <thead>
#     <tr>
#       <th id="T_906b8_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_906b8_level0_col1" class="col_heading level0 col1" >Location</th>
#       <th id="T_906b8_level0_col2" class="col_heading level0 col2" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_906b8_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_906b8_row0_col1" class="data row0 col1" >vegas</td>
#       <td id="T_906b8_row0_col2" class="data row0 col2" >53</td>
#     </tr>
#     <tr>
#       <td id="T_906b8_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_906b8_row1_col1" class="data row1 col1" >nyc</td>
#       <td id="T_906b8_row1_col2" class="data row1 col2" >21</td>
#     </tr>
#     <tr>
#       <td id="T_906b8_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_906b8_row2_col1" class="data row2 col1" >las vegas</td>
#       <td id="T_906b8_row2_col2" class="data row2 col2" >21</td>
#     </tr>
#     <tr>
#       <td id="T_906b8_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_906b8_row3_col1" class="data row3 col1" >ny</td>
#       <td id="T_906b8_row3_col2" class="data row3 col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_906b8_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_906b8_row4_col1" class="data row4 col1" >phoenix</td>
#       <td id="T_906b8_row4_col2" class="data row4 col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_906b8_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_906b8_row5_col1" class="data row5 col1" >new york</td>
#       <td id="T_906b8_row5_col2" class="data row5 col2" >18</td>
#     </tr>
#     <tr>
#       <td id="T_906b8_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_906b8_row6_col1" class="data row6 col1" >charlotte</td>
#       <td id="T_906b8_row6_col2" class="data row6 col2" >17</td>
#     </tr>
#     <tr>
#       <td id="T_906b8_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_906b8_row7_col1" class="data row7 col1" >eataly</td>
#       <td id="T_906b8_row7_col2" class="data row7 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_906b8_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_906b8_row8_col1" class="data row8 col1" >strip</td>
#       <td id="T_906b8_row8_col2" class="data row8 col2" >14</td>
#     </tr>
#     <tr>
#       <td id="T_906b8_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_906b8_row9_col1" class="data row9 col1" >chicago</td>
#       <td id="T_906b8_row9_col2" class="data row9 col2" >12</td>
#     </tr>
#     <tr>
#       <td id="T_906b8_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_906b8_row10_col1" class="data row10 col1" >manhattan</td>
#       <td id="T_906b8_row10_col2" class="data row10 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_906b8_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_906b8_row11_col1" class="data row11 col1" >arizona</td>
#       <td id="T_906b8_row11_col2" class="data row11 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_906b8_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_906b8_row12_col1" class="data row12 col1" >scottsdale</td>
#       <td id="T_906b8_row12_col2" class="data row12 col2" >8</td>
#     </tr>
#     <tr>
#       <td id="T_906b8_row13_col0" class="data row13 col0" >14</td>
#       <td id="T_906b8_row13_col1" class="data row13 col1" >california</td>
#       <td id="T_906b8_row13_col2" class="data row13 col2" >7</td>
#     </tr>
#     <tr>
#       <td id="T_906b8_row14_col0" class="data row14 col0" >15</td>
#       <td id="T_906b8_row14_col1" class="data row14 col1" >aria</td>
#       <td id="T_906b8_row14_col2" class="data row14 col2" >7</td>
#     </tr>
#   </tbody>
# </table>
# Saved: ner_top_locations.png

# %% [markdown]
# ## 9. Word Cloud — Entity ทั้งหมด
#
# Word Cloud รวม Entity ทุกประเภท — คำที่ใหญ่กว่า = ถูกพูดถึงบ่อยกว่า

# %%
entity_freq = ent_df['entity_norm'].value_counts().to_dict()

wc = WordCloud(
    width=1000,
    height=500,
    background_color='white',
    colormap='Blues',
    max_words=80,
    min_font_size=10
).generate_from_frequencies(entity_freq)

fig, ax = plt.subplots(figsize=(13, 6))
ax.imshow(wc, interpolation='bilinear')
ax.axis('off')
ax.set_title('Word Cloud — All Named Entities in Restaurant Reviews',
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('ner_wordcloud_all.png', bbox_inches='tight')
plt.show()
print('Saved: ner_wordcloud_all.png')
# Out:
# Saved: ner_wordcloud_all.png

# %% [markdown]
# ## 10. Cross-analysis: Entity x Sentiment
#
# เนื่องจากมี label Positive/Negative จาก Phase 1 สามารถตรวจสอบได้ว่า
# **Entity ใดมักปรากฏใน review แง่บวก หรือแง่ลบ?**
#
# *(Unsupervised Discovery ที่ validate ด้วย label ที่มีอยู่)*

# %%
TOP_N = 12
top_org_names = org_df['entity_norm'].value_counts().head(TOP_N).index.tolist()

org_sentiment = ent_df[
    (ent_df['label'] == 'ORG') &
    (ent_df['entity_norm'].isin(top_org_names))
].copy()

pivot = pd.crosstab(org_sentiment['entity_norm'], org_sentiment['sentiment'])
pivot = pivot.loc[pivot.sum(axis=1).sort_values(ascending=True).index]

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# ── Plot ซ้าย: Stacked Bar ──
ax1 = axes[0]
pivot.plot(kind='barh', stacked=True,
           color=['#e74c3c', '#2ecc71'],
           edgecolor='white', ax=ax1)
ax1.set_title('Top ORG — Mention Count by Sentiment', fontsize=12, fontweight='bold')
ax1.set_xlabel('Count')
ax1.set_ylabel('Entity (ORG)')
ax1.legend(title='Sentiment', loc='lower right')

# ── Plot ขวา: % Positive Bar ──
ax2 = axes[1]
ax2.spines[['top', 'right']].set_visible(False)

pct_pos = (pivot.get('Positive', 0) / pivot.sum(axis=1) * 100).sort_values()
colors_bar = ['#e74c3c' if v < 50 else '#2ecc71' for v in pct_pos.values]
bars = ax2.barh(pct_pos.index, pct_pos.values, color=colors_bar, edgecolor='white')
ax2.axvline(50, color='gray', linestyle='--', linewidth=1.2, alpha=0.7)
ax2.bar_label(bars, fmt='%.0f%%', padding=4, fontsize=9)
ax2.text(51, len(pct_pos) - 0.5, '50%', color='gray', fontsize=9)
ax2.set_xlabel('% Positive Reviews')
ax2.set_title('% Positive Mentions per ORG Entity', fontsize=12, fontweight='bold')
ax2.set_xlim(0, 115)

plt.suptitle('ORG Entity vs Sentiment Analysis', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('ner_entity_sentiment.png', bbox_inches='tight')
plt.show()
print('Saved: ner_entity_sentiment.png')
# Out:
# Saved: ner_entity_sentiment.png

# %% [markdown]
# ## 11. Summary Dashboard
#
# รวม 4 กราฟไว้ในหน้าเดียวเพื่อให้เห็นภาพรวมของ NER ทั้งหมด

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 12))
fig.suptitle('NER Summary Dashboard — Yelp Restaurant Reviews',
             fontsize=15, fontweight='bold', y=1.01)

# ── Plot 1: Pie — Entity Type Distribution ──
ax1 = axes[0, 0]
lbl_counts = ent_df['label'].value_counts()
ax1.pie(
    lbl_counts.values,
    labels=lbl_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=sns.color_palette('pastel'),
)
ax1.set_title('Entity Type Distribution', fontweight='bold')

# ── Plot 2: Bar — Top 10 ORG ──
ax2 = axes[0, 1]
top10_org = org_df['entity_norm'].value_counts().head(10)
sns.barplot(x=top10_org.values, y=top10_org.index, palette='Reds_r', ax=ax2)
ax2.bar_label(ax2.containers[0], fmt='%d', padding=3, fontsize=8)
ax2.set_title('Top 10 ORG Entities', fontweight='bold')
ax2.set_xlabel('Count')

# ── Plot 3: Bar — Top 10 PERSON ──
ax3 = axes[1, 0]
top10_person = person_df['entity_norm'].value_counts().head(10)
sns.barplot(x=top10_person.values, y=top10_person.index, palette='Blues_r', ax=ax3)
ax3.bar_label(ax3.containers[0], fmt='%d', padding=3, fontsize=8)
ax3.set_title('Top 10 PERSON Entities', fontweight='bold')
ax3.set_xlabel('Count')

# ── Plot 4: Bar — Top 10 GPE/LOC ──
ax4 = axes[1, 1]
top10_loc = location_df['entity_norm'].value_counts().head(10)
sns.barplot(x=top10_loc.values, y=top10_loc.index, palette='Greens_r', ax=ax4)
ax4.bar_label(ax4.containers[0], fmt='%d', padding=3, fontsize=8)
ax4.set_title('Top 10 Location (GPE + LOC) Entities', fontweight='bold')
ax4.set_xlabel('Count')

plt.tight_layout()
plt.savefig('ner_summary_dashboard.png', bbox_inches='tight')
plt.show()
print('Saved: ner_summary_dashboard.png')
# Out:
# Saved: ner_summary_dashboard.png

# %% [markdown]
# ## 12. ตัวอย่าง Review ที่มี Entity มากที่สุด
#
# ดู review ที่มี Entity หลากหลายที่สุด เพื่อยืนยันว่า spaCy จับได้ถูกต้อง

# %%
rich_rows = df.nlargest(5, 'entity_count')[['text', 'entities', 'entity_count', 'label_name']]

print('ตัวอย่าง Review ที่มี Entity มากที่สุด:')
print('=' * 65)
for _, row in rich_rows.iterrows():
    print(f'\n[Sentiment] {row["label_name"]}  |  Entity count: {row["entity_count"]}')
    preview = row['text'][:200] + '...' if len(row['text']) > 200 else row['text']
    print(f'[Text] {preview}')
    print('[Entities found]')
    for ent in row['entities']:
        print(f'  -> [{ent["label"]}]  {ent["text"]}')
    print('-' * 65)
# Out:
# ตัวอย่าง Review ที่มี Entity มากที่สุด:
# =================================================================
#
# [Sentiment] Negative  |  Entity count: 82
# [Text] Wir waren heute dort, anl\u00e4sslich unseres Hochzeitstages.\nIch war gespannt, wie sich uns das Lauerturmst\u00fcble pr\u00e4sentiert, nachdem ich hier doch sehr Gegens\u00e4tzliches gelesen hatte.\...
# [Entities found]
#   -> [ORG]  nachdem
#   -> [PERSON]  doch sehr
#   -> [PERSON]  gelesen hatte.\n\n\n
#   -> [PERSON]  \nIdyllisch
#   -> [ORG]  Charme
#   -> [ORG]  das
#   -> [PERSON]  Torbogen aus
#   -> [PERSON]  sch\u00f6n
#   -> [GPE]  Daf\u00fcr
#   -> [PERSON]  Stern
#   -> [PERSON]  das Lokal
#   -> [ORG]  Zwar
#   -> [PERSON]  sch\u00f6n
#   -> [PERSON]  k\u00f6nnte gem\u00fctlich
#   -> [PERSON]  extrem klein
#   -> [PERSON]  Leider
#   -> [ORG]  bin nicht
#   -> [PERSON]  Mann
#   -> [PERSON]  zu eng.
#   -> [PERSON]  der zweite Stern.\nAllerdings
#   -> [PERSON]  Zack
#   -> [PERSON]  notiert hatte
#   -> [PERSON]  hatte
#   -> [PERSON]  Reservierung
#   -> [PRODUCT]  Hochzeitstag
#   -> [PERSON]  h\u00e4tte uns mit
#   -> [PERSON]  Sicht
#   -> [PERSON]  k\u00f6nnen.\nDie Apfelschorle
#   -> [PERSON]  schmeckte leider garnicht
#   -> [PERSON]  Wie
#   -> [ORG]  Billig-Konzentrat
#   -> [PERSON]  wurde dort gemischt
#   -> [PERSON]  hatte gefragt vorab).\nDie Karte
#   -> [GPE]  \u00fcbersichtlich
#   -> [GPE]  klein
#   -> [ORG]  Schnitzel
#   -> [PERSON]  Fritten
#   -> [ORG]  Salat
#   -> [PRODUCT]  J\u00e4gersauce
#   -> [PERSON]  mein Mann
#   -> [PERSON]  waren frisch
#   -> [ORG]  Salat
#   -> [PERSON]  Sauce
#   -> [ORG]  dem Blattsalat
#   -> [PERSON]  Hatte
#   -> [GPE]  Kommentar
#   -> [PERSON]  Salatteller
#   -> [ORG]  Die Schnitzel
#   -> [PERSON]  waren ziemlich viel
#   -> [ORG]  nicht aus
#   -> [PERSON]  Dose
#   -> [PERSON]  Meine J\u00e4gersauce
#   -> [PERSON]  waren frisch
#   -> [PERSON]  Sauce
#   -> [ORG]  Pommes
#   -> [PRODUCT]  hatte
#   -> [ORG]  Tische
#   -> [ORG]  Raum
#   -> [PERSON]  Bedienung
#   -> [PERSON]  Tisch
#   -> [ORG]  Nachbartisch
#   -> [PERSON]  Karten
#   -> [ORG]  geht garnicht.\nAn
#   -> [PERSON]  Jubi-Essen
#   -> [PERSON]  zu laut
#   -> [PERSON]  geht leider
#   -> [PERSON]  Anzahl
#   -> [PERSON]  Kosten der G\u00e4ste und
#   -> [PERSON]  \nIm Sommer
#   -> [PERSON]  zum Drau\u00dfen
#   -> [PERSON]  kann ich
#   -> [PERSON]  nicht beurteilen
#   -> [ORG]  Einrichtungen
#   -> [ORG]  von uns nicht genutzt wurde
#   -> [PERSON]  Unterm Strich
#   -> [PERSON]  hatte das Ganze
#   -> [PRODUCT]  sa\u00df
#   -> [GPE]  Nachbarin
#   -> [ORG]  Nebentisch
#   -> [PERSON]  Teil
#   -> [PERSON]  Kette
#   -> [PERSON]  Fallen
# -----------------------------------------------------------------
#
# [Sentiment] Negative  |  Entity count: 25
# [Text] Sad sad sad.\n\nAs everyone in Charlotte surely knows by now, there are not a lot of dim sum options in the city.  That being said, the two Charlotte dim sum restaurants (Dragon Court, Dim Sum Restaur...
# [Entities found]
#   -> [GPE]  Charlotte
#   -> [GPE]  Charlotte
#   -> [ORG]  Dragon Court
#   -> [PERSON]  Dim Sum Restaurant
#   -> [DATE]  their best days
#   -> [GPE]  Vancouver
#   -> [DATE]  Christmas day
#   -> [GPE]  Charlotte
#   -> [ORG]  Dragon Court
#   -> [ORG]  Dragon Court
#   -> [PERSON]  WTF?\n\nTHE GOOD\n\nCheng Fun
#   -> [ORG]  BBQ
#   -> [PERSON]  cheng
#   -> [PERSON]  cheng
#   -> [GPE]  ZERO
#   -> [PERSON]  Carrot
#   -> [TIME]  about 10 minutes
#   -> [TIME]  an additional 10 minutes
#   -> [TIME]  20 minutes
#   -> [ORG]  Dragon Court
#   -> [TIME]  hours
#   -> [DATE]  Christmas
#   -> [DATE]  Christmas
#   -> [GPE]  Charlotte
#   -> [ORG]  Dragon Court
# -----------------------------------------------------------------
#
# [Sentiment] Positive  |  Entity count: 25
# [Text] letztens musste ich im schnelldurchlauf noch einige sachen kaufen, anzug, schuhe, etc. bin daraufhin zu breuninger gegangen, da ich aufgrund knapper zeit einen laden wollte, in dem ich alles unter ein...
# [Entities found]
#   -> [PERSON]  letztens musste
#   -> [PERSON]  schnelldurchlauf noch einige
#   -> [PERSON]  bin daraufhin zu breuninger gegangen
#   -> [PERSON]  knapper zeit
#   -> [PERSON]  kann
#   -> [PERSON]  \nin der herrenabteilung
#   -> [PERSON]  wurde dann
#   -> [PERSON]  anprobieren angesprochen
#   -> [PERSON]  bin daraufhin sehr gut
#   -> [PERSON]  der krawatte
#   -> [ORG]  \nder
#   -> [ORG]  mann
#   -> [PERSON]  daraus wurde
#   -> [PERSON]  bin kein
#   -> [PERSON]  von kundenkarten
#   -> [PERSON]  wurde
#   -> [PERSON]  diskret
#   -> [PERSON]  davon abgesehen
#   -> [PERSON]  klassischen bedarf
#   -> [PERSON]  von guter
#   -> [PERSON]  qualit\u00e4t.
#   -> [PERSON]  aktuellen kollektionen mit
#   -> [PERSON]  erdgeschoss w\u00fcrde
#   -> [PRODUCT]  das ist
#   -> [PERSON]  mal der zeitgeist
# -----------------------------------------------------------------
#
# [Sentiment] Positive  |  Entity count: 25
# [Text] **Summary**\n       - Flavor - Everything we had was either good or great. It was definitely a treat for the taste buds.\n       - Authentic - From the decor to the staff to the food, this is truly an...
# [Entities found]
#   -> [ORG]  buds.\n       - Authentic - From
#   -> [ORG]  perfectly.\n       - Value - You
#   -> [PERSON]  Ichiza
#   -> [PERSON]  Ichiza
#   -> [PERSON]  Salmon Salad -
#   -> [PERSON]  Salmon
#   -> [PRODUCT]  http://www.yelp.com/biz_photos/82YGtjc5KKikNiqBZ33qzw?select=IoNSnP5EADvdByH5lc0Okg).\n       - $
#   -> [ORG]  Garlic Potato - An
#   -> [PRODUCT]  disappointed.\n       - $
#   -> [ORG]  Shoniku - Chicken
#   -> [ORG]  Negi Ma - Chicken
#   -> [ORG]  Butabara - Pork
#   -> [ORG]  ratio.\n       - $1.90
#   -> [ORG]  Sunagimo - Chicken Gizzard
#   -> [PERSON]  gizzards.\n**Mini Meals**\n       -
#   -> [PERSON]  Zuke Don - Marinated
#   -> [PRODUCT]  though.\n       - $
#   -> [PERSON]  Koro Steak -
#   -> [ORG]  Chawan Mushi - Steamed
#   -> [GPE]  Vegas
#   -> [GPE]  Vegas
#   -> [ORG]  Ichiza
#   -> [PERSON]  Yamaimo Teppan - I
#   -> [MONEY]  salty.\n       - $6.50
#   -> [TIME]  15 minutes
# -----------------------------------------------------------------
#
# [Sentiment] Negative  |  Entity count: 22
# [Text] Bordering near 3 stars.\n\nI had to wait like 6 years to finally eat at The Buffet at the Wynn!  And, wow, I ended up not being as enamored as I thought I would be.  I think I was spoiled a bit from o...
# [Entities found]
#   -> [DATE]  like 6 years
#   -> [TIME]  a lovely afternoon
#   -> [LOC]  wifey
#   -> [LOC]  Strip
#   -> [PERSON]  Line
#   -> [TIME]  about 25 minutes
#   -> [PERSON]  Nah
#   -> [ORG]  Buffet
#   -> [ORG]  Costco
#   -> [ORG]  Buffet
#   -> [ORG]  TOO
#   -> [LOC]  wifey
#   -> [PERSON]  Buffet
#   -> [GPE]  Wynn
#   -> [PRODUCT]  Damn
#   -> [GPE]  Disappointing
#   -> [PERSON]  Wynn
#   -> [GPE]  Macau
#   -> [DATE]  that day
#   -> [PERSON]  Soggy
#   -> [PERSON]  Rice
#   -> [DATE]  another 6 years
# -----------------------------------------------------------------

# %% [markdown]
# ## 13. Export ผลลัพธ์ไฟล์ CSV

# %%
ent_summary = (
    ent_df.groupby(['label', 'entity_norm'])
    .agg(count=('entity', 'count'))
    .reset_index()
    .sort_values(['label', 'count'], ascending=[True, False])
)
ent_summary.to_csv('ner_entity_summary.csv', index=False, encoding='utf-8-sig')
print('Saved: ner_entity_summary.csv')
print(f'Total rows: {len(ent_summary):,}')
display(ent_summary.head(10))
# Out:
# Saved: ner_entity_summary.csv
# Total rows: 2,685
#     label   entity_norm  count
# 284  DATE         today     32
# 137  DATE        friday     17
# 207  DATE        sunday     17
# 198  DATE      saturday     15
# 307  DATE     yesterday     12
# 225  DATE       the day     11
# 257  DATE    the summer     10
# 158  DATE     last week      7
# 246  DATE  the next day      7
# 306  DATE         years      7

# %% [markdown]
# ---
# ## 14. อภิปรายผล (Discussion)
#
# ### 14.1 Entity ที่พบมากที่สุด
#
# | Entity Type | ที่พบ | ความหมายใน Restaurant Domain |
# |-------------|------|------------------------------|
# | `ORG` | ชื่อร้าน / แบรนด์ | สะท้อนว่า reviewer กล่าวถึงชื่อร้านโดยตรง |
# | `PERSON` | ชื่อ staff / chef | มักปรากฏเมื่อพูดถึงบริการที่ประทับใจหรือแย่มาก |
# | `GPE` | เมือง / ย่าน | บอก context ว่าเป็น review จากพื้นที่ไหน |
# | `DATE/TIME` | วันเวลา | มักปรากฏในเรื่อง wait time, reservation |
#
# ### 14.2 Entity กับ Sentiment
#
# - ORG ที่มี % Positive สูง -> ร้านที่ได้รับการกล่าวถึงในทางดี
# - ORG ที่มี % Positive ต่ำ -> ร้านที่มักถูกร้องเรียน
# - PERSON ที่พบบ่อยในบริบทลบ มักเป็นชื่อ staff ที่ reviewer ร้องเรียน
#
# ### 14.3 ข้อจำกัดของ Pre-trained Model และการแก้ไข
#
# - `en_core_web_sm` จำแนก Entity ผิดบ่อยในบริบท restaurant review เช่น `un`, `az`, `never`, `free`, `awesome` ถูก tag เป็น ORG
# - **แก้ไข:** เพิ่ม post-filtering 5 rules — blacklist 30+ คำ + min_length + pattern filter
# - false-positive ถูกกรองออกก่อน plot ทุก visualization
# - ชื่อร้านที่เป็นคำทั่วไป
#   (เช่น 'The Grill') อาจถูก tag เป็น PRODUCT แทน ORG
# - Model นี้ train บน general text ไม่ใช่ restaurant domain โดยเฉพาะ
# - ชื่อร้านที่สะกดหลายรูปแบบ นับแยกกัน -> แก้ได้ด้วย entity normalization เพิ่มเติม
#
# ### 14.4 AI Audit Log
#
# | Task | Prompt ที่ใช้ | ผลจาก AI | การตรวจสอบและแก้ไข |
# |------|-------------|----------|-----------------------|
# | NER pipeline | Build spaCy NER pipeline for restaurant reviews | โครงสร้างถูกต้อง | ตรวจสอบ entity label ด้วย review จริง |
# | Visualization | Entity vs Sentiment stacked bar chart | Code ใช้งานได้ | ปรับ color scheme และ axis label |
# | Entity normalization | Normalize entity names for deduplication | ใช้ .lower().strip() | เพิ่ม edge case สำหรับ possessive 's |
